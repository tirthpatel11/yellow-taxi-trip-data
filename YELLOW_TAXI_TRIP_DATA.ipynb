# %%
#que1(1)
import pandas as pd
df = pd.read_csv('2017_Yellow_Taxi_Trip_Data.csv')
df
# Out:
#        Unnamed: 0  VendorID    tpep_pickup_datetime   tpep_dropoff_datetime  \
# 0        24870114         2   03/25/2017 8:55:43 AM   03/25/2017 9:09:47 AM
# 1        35634249         1   04/11/2017 2:53:28 PM   04/11/2017 3:19:58 PM
# 2       106203690         1   12/15/2017 7:26:56 AM   12/15/2017 7:34:08 AM
# 3        38942136         2   05/07/2017 1:17:59 PM   05/07/2017 1:48:14 PM
# 4        30841670         2  04/15/2017 11:32:20 PM  04/15/2017 11:49:03 PM
# ...           ...       ...                     ...                     ...
# 22694    14873857         2   02/24/2017 5:37:23 PM   02/24/2017 5:40:39 PM
# 22695    66632549         2   08/06/2017 4:43:59 PM   08/06/2017 5:24:47 PM
# 22696    74239933         2   09/04/2017 2:54:14 PM   09/04/2017 2:58:22 PM
# 22697    60217333         2  07/15/2017 12:56:30 PM   07/15/2017 1:08:26 PM
# 22698    17208911         1   03/02/2017 1:02:49 PM   03/02/2017 1:16:09 PM
#
# ...

# %%
df.info()
#there are 3 data types: int64, object and float64
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22699 entries, 0 to 22698
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             22699 non-null  int64
#  1   VendorID               22699 non-null  int64
#  2   tpep_pickup_datetime   22699 non-null  object
#  3   tpep_dropoff_datetime  22699 non-null  object
#  4   passenger_count        22699 non-null  int64
#  5   trip_distance          22699 non-null  float64
#  6   RatecodeID             22699 non-null  int64
#  7   store_and_fwd_flag     22699 non-null  object
#  8   PULocationID           22699 non-null  int64
#  9   DOLocationID           22699 non-null  int64
#  10  payment_type           22699 non-null  int64
#  11  fare_amount            22699 non-null  float64
#  12  extra                  22699 non-null  float64
#  13  mta_tax                22699 non-null  float64
# ...

# %%
df.isnull().sum()
#no null objects
# Out:
# Unnamed: 0               0
# VendorID                 0
# tpep_pickup_datetime     0
# tpep_dropoff_datetime    0
# passenger_count          0
# trip_distance            0
# RatecodeID               0
# store_and_fwd_flag       0
# PULocationID             0
# DOLocationID             0
# payment_type             0
# fare_amount              0
# extra                    0
# mta_tax                  0
# tip_amount               0
# tolls_amount             0
# improvement_surcharge    0
# total_amount             0
# dtype: int64

# %%
#que1(2)
df.describe()
"""
1.yes, the minimum amount ins the fare amount is negative and extra is also negative
2. ratecodeid ranges from 1 to 6 but max was 99
"""
# Out:
#          Unnamed: 0      VendorID  passenger_count  trip_distance  \
# count  2.269900e+04  22699.000000     22699.000000   22699.000000
# mean   5.675849e+07      1.556236         1.642319       2.913313
# std    3.274493e+07      0.496838         1.285231       3.653171
# min    1.212700e+04      1.000000         0.000000       0.000000
# 25%    2.852056e+07      1.000000         1.000000       0.990000
# 50%    5.673150e+07      2.000000         1.000000       1.610000
# 75%    8.537452e+07      2.000000         2.000000       3.060000
# max    1.134863e+08      2.000000         6.000000      33.960000
#
#          RatecodeID  PULocationID  DOLocationID  payment_type   fare_amount  \
# count  22699.000000  22699.000000  22699.000000  22699.000000  22699.000000
# mean       1.043394    162.412353    161.527997      1.336887     13.026629
# std        0.708391     66.633373     70.139691      0.496211     13.243791
# ...

# %%
"""
summary:

It can be infered that the model mainly depends on trip_distance and total_amount 
factors. So, first remove all the columns which have no weightage in training 
the model like 'tpep_pickup_datetime', 'tpep_dropoff_datetime', 'store_and_fwd_flag'
and train it with randomforestregressor model because it requires less preprocessing 
than other models. It also performs well for regression problems which makes it
a good option for predicting modeling tasks.

"""
# Out:
# '\n# summary about the data to inform next steps:\n\n\n'

# %%
#que 2(1)
sorted_df = df.sort_values(by='trip_distance', ascending=False)
sorted_df['trip_distance']
#distance is in zero
# Out:
# 9280     33.96
# 13861    33.92
# 6064     32.72
# 10291    31.95
# 29       30.83
#          ...
# 2440      0.00
# 15916     0.00
# 1350      0.00
# 246       0.00
# 17788     0.00
# Name: trip_distance, Length: 22699, dtype: float64

# %%
#que 2(2)
sorted_df = df.sort_values(by='total_amount', ascending=False)
sorted_df['total_amount']
#it is observed that total amount is negative
# Out:
# 8476     1200.29
# 20312     450.30
# 13861     258.21
# 12511     233.74
# 15474     211.80
#           ...
# 11204      -5.30
# 14714      -5.30
# 17602      -5.80
# 20698      -5.80
# 12944    -120.30
# Name: total_amount, Length: 22699, dtype: float64

# %%
#que 2(3)
"""
no, the resulting rows are not similar for both sorts because the values
differ for various factors like tip amount, fare 
amount(due to pickup and drop off location).
"""
# Out:
# '\nno, the resulting rows are not similar for both sorts because the values\ndiffer for various factors like tip amount, fare \namount(due to pickup and drop off location).\n'

# %%
#que 3

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

# %%
df_dummies = pd.get_dummies(df, columns=['store_and_fwd_flag'])

# %%
df_comb = pd.concat([df, df_dummies], axis =1)

# %%
X = df_comb.drop(['tpep_pickup_datetime', 'tpep_dropoff_datetime', 'store_and_fwd_flag'], axis=1)

# %%
Y = df_comb['total_amount']

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
model = RandomForestRegressor()
model.fit(X_train, Y_train)
# Out:
# RandomForestRegressor()

# %%
Y_pred = model.predict(X_test)

# %%
mae = mean_absolute_error(Y_test, Y_pred)
mse = mean_squared_error(Y_test, Y_pred)
rmse = np.sqrt(mse)

# %%
r2 = r2_score(Y_test, Y_pred)

# %%
print("mean absolute error(mae):", mae)
print("mean squared error(mse):", mse)
print("root mean squared error(rmse):", rmse)
print(f"prediction accuracy: {r2 * 100:.2f}%")
# Out:
# mean absolute error(mae): 0.20461922907489533
# mean squared error(mse): 171.51719519576437
# root mean squared error(rmse): 13.096457352878463
# prediction accuracy: 64.56%
